# %% [markdown]
# # MACHINE LEARNING PROJECT

# %% [markdown]
# # ZEPHYR TECHNOLOGY

# %% [markdown]
# # Name        :   Shreya HM
# # Branch      :   B.Tech Data Science
# # Dataset      : covid vaccine vs. death

# %% [markdown]
# Description: To predict the vaccinations vs death rate

# %% [markdown]
# # Importing all libraries and import data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("covid_vaccination_vs_death_ratio.csv")
data
# Out:
#        Unnamed: 0      country iso_code        date  total_vaccinations  \
# 0               0  Afghanistan      AFG  2021-05-11            504502.0
# 1               1  Afghanistan      AFG  2021-05-20            547901.0
# 2               2  Afghanistan      AFG  2021-05-24            573277.0
# 3               3  Afghanistan      AFG  2021-05-26            590454.0
# 4               4  Afghanistan      AFG  2021-05-27            593313.0
# ...           ...          ...      ...         ...                 ...
# 19252       19252     Zimbabwe      ZWE  2021-09-21           5084031.0
# 19253       19253     Zimbabwe      ZWE  2021-09-22           5123522.0
# 19254       19254     Zimbabwe      ZWE  2021-09-23           5166508.0
# 19255       19255     Zimbabwe      ZWE  2021-09-24           5197363.0
# 19256       19256     Zimbabwe      ZWE  2021-09-25           5218672.0
#
#        people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# ...

# %%
data.shape
# Out:
# (19257, 10)

# %%
data.head(500)
# Out:
#      Unnamed: 0      country iso_code        date  total_vaccinations  \
# 0             0  Afghanistan      AFG  2021-05-11            504502.0
# 1             1  Afghanistan      AFG  2021-05-20            547901.0
# 2             2  Afghanistan      AFG  2021-05-24            573277.0
# 3             3  Afghanistan      AFG  2021-05-26            590454.0
# 4             4  Afghanistan      AFG  2021-05-27            593313.0
# ..          ...          ...      ...         ...                 ...
# 495         495        Aruba      ABW  2021-04-16             52955.0
# 496         496        Aruba      ABW  2021-04-17             55582.0
# 497         497        Aruba      ABW  2021-04-18             55651.0
# 498         498        Aruba      ABW  2021-04-19             58178.0
# 499         499        Aruba      ABW  2021-04-20             60379.0
#
#      people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# ...

# %%
data.tail(1200)
# Out:
#        Unnamed: 0   country iso_code        date  total_vaccinations  \
# 18057       18057   Ukraine      UKR  2021-08-11           7008448.0
# 18058       18058   Ukraine      UKR  2021-08-12           7171758.0
# 18059       18059   Ukraine      UKR  2021-08-13           7332550.0
# 18060       18060   Ukraine      UKR  2021-08-14           7409698.0
# 18061       18061   Ukraine      UKR  2021-08-15           7460766.0
# ...           ...       ...      ...         ...                 ...
# 19252       19252  Zimbabwe      ZWE  2021-09-21           5084031.0
# 19253       19253  Zimbabwe      ZWE  2021-09-22           5123522.0
# 19254       19254  Zimbabwe      ZWE  2021-09-23           5166508.0
# 19255       19255  Zimbabwe      ZWE  2021-09-24           5197363.0
# 19256       19256  Zimbabwe      ZWE  2021-09-25           5218672.0
#
#        people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0  total_vaccinations  people_vaccinated  \
# count  19257.000000        1.925700e+04       1.925700e+04
# mean    9628.000000        1.657053e+07       1.072298e+07
# std     5559.161403        5.887682e+07       3.918869e+07
# min        0.000000        1.630000e+02       1.620000e+02
# 25%     4814.000000        3.811710e+05       2.817130e+05
# 50%     9628.000000        2.108172e+06       1.382831e+06
# 75%    14442.000000        9.987918e+06       5.760947e+06
# max    19256.000000        2.174043e+09       1.100842e+09
#
#        people_fully_vaccinated    New_deaths    population         ratio
# count             1.925700e+04  19257.000000  1.925700e+04  19257.000000
# mean              5.987480e+06    110.592927  4.823571e+07     28.595815
# std               2.167499e+07    357.610074  1.553499e+08     24.389301
# min               1.000000e+00    -41.000000  1.619000e+03      0.002980
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'New_deaths',
#        'population', 'ratio'],
#       dtype='object')

# %%
# To check Null values
data.isnull().sum()
# Out:
# Unnamed: 0                 0
# country                    0
# iso_code                   0
# date                       0
# total_vaccinations         0
# people_vaccinated          0
# people_fully_vaccinated    0
# New_deaths                 0
# population                 0
# ratio                      0
# dtype: int64

# %%
#Converting catogorical data into Numerical data
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
data['country']=lb.fit_transform(data['country'])

# %%
data.head()
# Out:
#    Unnamed: 0  country iso_code        date  total_vaccinations  \
# 0           0        0      AFG  2021-05-11            504502.0
# 1           1        0      AFG  2021-05-20            547901.0
# 2           2        0      AFG  2021-05-24            573277.0
# 3           3        0      AFG  2021-05-26            590454.0
# 4           4        0      AFG  2021-05-27            593313.0
#
#    people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# 0           448878.0                  55624.0          12  40064421.0
# 1           470341.0                  77560.0          10  40064421.0
# 2           476367.0                  96910.0          10  40064421.0
# 3           479372.0                 111082.0          19  40064421.0
# 4           479574.0                 113739.0          14  40064421.0
#
#       ratio
# 0  1.120391
# 1  1.173962
# 2  1.189003
# 3  1.196503
# 4  1.197007

# %%
data['iso_code']=lb.fit_transform(data['iso_code'])
data.head()
# Out:
#    Unnamed: 0  country  iso_code        date  total_vaccinations  \
# 0           0        0         1  2021-05-11            504502.0
# 1           1        0         1  2021-05-20            547901.0
# 2           2        0         1  2021-05-24            573277.0
# 3           3        0         1  2021-05-26            590454.0
# 4           4        0         1  2021-05-27            593313.0
#
#    people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# 0           448878.0                  55624.0          12  40064421.0
# 1           470341.0                  77560.0          10  40064421.0
# 2           476367.0                  96910.0          10  40064421.0
# 3           479372.0                 111082.0          19  40064421.0
# 4           479574.0                 113739.0          14  40064421.0
#
#       ratio
# 0  1.120391
# 1  1.173962
# 2  1.189003
# 3  1.196503
# 4  1.197007

# %%
data['iso_code']=lb.fit_transform(data['iso_code'])
data['date']=lb.fit_transform(data['date'])
data.head()
# Out:
#    Unnamed: 0  country  iso_code  date  total_vaccinations  people_vaccinated  \
# 0           0        0         1   135            504502.0           448878.0
# 1           1        0         1   144            547901.0           470341.0
# 2           2        0         1   148            573277.0           476367.0
# 3           3        0         1   150            590454.0           479372.0
# 4           4        0         1   151            593313.0           479574.0
#
#    people_fully_vaccinated  New_deaths  population     ratio
# 0                  55624.0          12  40064421.0  1.120391
# 1                  77560.0          10  40064421.0  1.173962
# 2                  96910.0          10  40064421.0  1.189003
# 3                 111082.0          19  40064421.0  1.196503
# 4                 113739.0          14  40064421.0  1.197007

# %%
data['total_vaccinations']=lb.fit_transform(data['total_vaccinations'])
data.head()
# Out:
#    Unnamed: 0  country  iso_code  date  total_vaccinations  people_vaccinated  \
# 0           0        0         1   135                5252           448878.0
# 1           1        0         1   144                5463           470341.0
# 2           2        0         1   148                5558           476367.0
# 3           3        0         1   150                5639           479372.0
# 4           4        0         1   151                5652           479574.0
#
#    people_fully_vaccinated  New_deaths  population     ratio
# 0                  55624.0          12  40064421.0  1.120391
# 1                  77560.0          10  40064421.0  1.173962
# 2                  96910.0          10  40064421.0  1.189003
# 3                 111082.0          19  40064421.0  1.196503
# 4                 113739.0          14  40064421.0  1.197007

# %%
data['people_vaccinated']=lb.fit_transform(data['people_vaccinated'])
data.head()
# Out:
#    Unnamed: 0  country  iso_code  date  total_vaccinations  people_vaccinated  \
# 0           0        0         1   135                5252               5788
# 1           1        0         1   144                5463               5915
# 2           2        0         1   148                5558               5942
# 3           3        0         1   150                5639               5960
# 4           4        0         1   151                5652               5962
#
#    people_fully_vaccinated  New_deaths  population     ratio
# 0                  55624.0          12  40064421.0  1.120391
# 1                  77560.0          10  40064421.0  1.173962
# 2                  96910.0          10  40064421.0  1.189003
# 3                 111082.0          19  40064421.0  1.196503
# 4                 113739.0          14  40064421.0  1.197007

# %%
data['people_fully_vaccinated']=lb.fit_transform(data['people_fully_vaccinated'])
data.head()
# Out:
#    Unnamed: 0  country  iso_code  date  total_vaccinations  people_vaccinated  \
# 0           0        0         1   135                5252               5788
# 1           1        0         1   144                5463               5915
# 2           2        0         1   148                5558               5942
# 3           3        0         1   150                5639               5960
# 4           4        0         1   151                5652               5962
#
#    people_fully_vaccinated  New_deaths  population     ratio
# 0                     3281          12  40064421.0  1.120391
# 1                     3903          10  40064421.0  1.173962
# 2                     4313          10  40064421.0  1.189003
# 3                     4527          19  40064421.0  1.196503
# 4                     4562          14  40064421.0  1.197007

# %%
data['population']=lb.fit_transform(data['population'])
data.head()
# Out:
#    Unnamed: 0  country  iso_code  date  total_vaccinations  people_vaccinated  \
# 0           0        0         1   135                5252               5788
# 1           1        0         1   144                5463               5915
# 2           2        0         1   148                5558               5942
# 3           3        0         1   150                5639               5960
# 4           4        0         1   151                5652               5962
#
#    people_fully_vaccinated  New_deaths  population     ratio
# 0                     3281          12         162  1.120391
# 1                     3903          10         162  1.173962
# 2                     4313          10         162  1.189003
# 3                     4527          19         162  1.196503
# 4                     4562          14         162  1.197007

# %%
data['ratio']=lb.fit_transform(data['ratio'])
data.head()
# Out:
#    Unnamed: 0  country  iso_code  date  total_vaccinations  people_vaccinated  \
# 0           0        0         1   135                5252               5788
# 1           1        0         1   144                5463               5915
# 2           2        0         1   148                5558               5942
# 3           3        0         1   150                5639               5960
# 4           4        0         1   151                5652               5962
#
#    people_fully_vaccinated  New_deaths  population  ratio
# 0                     3281          12         162   1069
# 1                     3903          10         162   1107
# 2                     4313          10         162   1119
# 3                     4527          19         162   1130
# 4                     4562          14         162   1131

# %%
data.shape
# Out:
# (19257, 10)

# %% [markdown]
# # DATA VISUALIZATION

# %%
#Ploting the graphs
data.plot(x='total_vaccinations',y='New_deaths',style='s')
plt.title('total vaccinations vs death rate')
plt.xlabel('total vaccinated')
plt.ylabel('death rate')
plt.show()

# %%
data.plot(x='people_fully_vaccinated',y='New_deaths',style='o')
plt.title('total vaccinations vs death rate')
plt.xlabel('total vaccinated')
plt.ylabel('death rate')
plt.show()

# %%
data.plot(x='country',y='New_deaths',style='o')
plt.title('total vaccinations vs death rate')
plt.xlabel('total vaccinated')
plt.ylabel('death rate')
plt.show()

# %%
data.plot(x='ratio',y='New_deaths',style='o')
plt.title('total vaccinations vs death rate')
plt.xlabel('total vaccinated')
plt.ylabel('death rate')
plt.show()

# %%
data.plot(x='country',y='New_deaths',style='s')
plt.title('total vaccinations vs death rate')
plt.xlabel('total vaccinated')
plt.ylabel('death rate')
plt.show()

# %%
#preparing the data 
x=data.iloc[:,0:-1]
x
# Out:
#        Unnamed: 0  country  iso_code  date  total_vaccinations  \
# 0               0        0         1   135                5252
# 1               1        0         1   144                5463
# 2               2        0         1   148                5558
# 3               3        0         1   150                5639
# 4               4        0         1   151                5652
# ...           ...      ...       ...   ...                 ...
# 19252       19252      196       197   268               12195
# 19253       19253      196       197   269               12221
# 19254       19254      196       197   270               12238
# 19255       19255      196       197   271               12261
# 19256       19256      196       197   272               12272
#
#        people_vaccinated  people_fully_vaccinated  New_deaths  population
# 0                   5788                     3281          12         162
# ...

# %%
y=data.iloc[:,-1]
y
# Out:
# 0        1069
# 1        1107
# 2        1119
# 3        1130
# 4        1131
#          ...
# 19252    8885
# 19253    8914
# 19254    8947
# 19255    8977
# 19256    8987
# Name: ratio, Length: 19257, dtype: int64

# %%
#split this data into training and test sets

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# testing the Algorithm by using Linear Regression
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=linreg.predict(x_test)

# %%
np.round(linreg.score(x_train,y_train)*100,2)
# Out:
# 81.91

# %%
np.round(linreg.score(x_test,y_test)*100,2)
# Out:
# 81.88

# %% [markdown]
# conclusion:VSD mortality rates demonstrate a healthy vaccinee effect, with rates lowest in the days immediately following vaccination, most apparent in the older age groups. The VSD mortality rate is lower than that in the general U.S. population, and the causes of death are similar.
